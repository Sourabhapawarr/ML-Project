# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.chdir('C:\\Users\\HP\\OneDrive')

# %%
sales = pd.read_csv('BigMartSalesData.csv')
sales
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541869    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541870    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541871    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541872    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541873    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#         UnitPrice  Amount InvoiceDate  Day  Month  Year  CustomerID  \
# ...

# %%
#1.Plot Total Sales Per Month for Year 2011. How the total sales have increased over months in Year 2011. 
#Which month has lowest Sales?

# %%
total_month_sale = sales.groupby('Month').agg({'Amount':np.sum})
total_month_sale
# Out:
#             Amount
# Month
# 1       822669.640
# 2       549134.460
# 3       752003.310
# 4       582318.451
# 5       817655.200
# 6       832231.670
# 7       757108.941
# 8       791173.020
# 9      1097467.722
# 10     1239237.260
# 11     1557236.410
# 12     1742367.690

# %%
plt.plot(total_month_sale.index,total_month_sale.values)
plt.xlabel("Years")
plt.ylabel("Sales")
plt.title("2011 Sales Report")
plt.show()

# %%
#2.Plot Total Sales Per Month for Year 2011 as Bar Chart. Is Bar Chart Better to visualize than Simple Plot?

# %%
sales.groupby('Month').agg({'Amount':np.sum}).plot(kind='bar', color='orange')
plt.xlabel('Year of 2011')
plt.ylabel('Total Sales')
plt.title('Sales Per Month in 2011')
plt.show()

# %%
#3. Plot Pie Chart for Year 2011 Country Wise. Which Country contributes highest towards sales?

# %%
sales_country = sales.groupby('Country').agg({'Amount':np.sum})
sales_country
# Out:
#                            Amount
# Country
# Australia              139965.350
# Austria                 10243.040
# Bahrain                   959.880
# Belgium                 41481.720
# Brazil                   1143.600
# Canada                   3666.380
# Channel Islands         20814.590
# Cyprus                  14234.470
# Czech Republic            945.760
# Denmark                 19142.540
# EIRE                   303631.100
# European Community       1308.750
# Finland                 22765.420
# France                 222026.320
# Germany                236036.070
# Greece                   4810.520
# Hong Kong               21266.560
# Iceland                  4310.000
# Israel                   8362.700
# Italy                   18075.970
# Japan                   39492.120
# Lebanon                  1693.880
# Lithuania                1661.060
# Malta                    2945.710
# Netherlands            286231.140
# Norway                  37167.420
# ...

# %%
df_grouped_country = sales.query("Year == 2011").filter(
    ["Country", "Amount"]).groupby(["Country"], as_index=False).sum()

plt.pie(df_grouped_country["Amount"],
        labels=df_grouped_country["Country"],
        autopct='%1.1f%%',
        shadow=True)

plt.tight_layout()
plt.show()

# %%
#4.Plot Scatter Plot for the invoice amounts and see the concentration of amount. 
#In which range most of the invoice amounts are concentrated

# %%
sales_invoice = sales.groupby('InvoiceNo').agg({'Amount':np.sum})
print (sales_invoice)
plt.scatter(sales_invoice.values,sales_invoice.values,color='b')
plt.grid(True)
plt.show()
# Out:
#               Amount
# InvoiceNo
# 536365        139.12
# 536366         22.20
# 536367        278.73
# 536368         70.05
# 536369         17.85
# ...              ...
# C581484    168469.60
# C581490        32.53
# C581499       224.69
# C581568        54.75
# C581569         7.50
#
# [25897 rows x 1 columns]
